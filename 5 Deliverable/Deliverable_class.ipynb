# %% [markdown]
# # Deliverable Notebook

# %%
import pandas as pd
import re
pd.set_option('display.max_rows', None)

# %% [markdown]
# Drug Classes:
# - ALLERGY, SYSTEMIC & NASAL
# - DERMATOLOGICS
# - GI PRODUCTS
# - IMMUNOLOGY
# - MULTIPLE SCLEROSIS
# - NERVOUS SYSTEM DISORDERS
# - ONCOLOGICS
# - OPHTHALMOLOGY, GENERAL
# - OTHER CNS
# - OTHER HAEMATOLOGICALS
# - VACCINES (PURE, COMB, OTHER)

# %%
classes = ['ALLERGY, SYSTEMIC & NASAL', 'DERMATOLOGICS', 'GI PRODUCTS', 'IMMUNOLOGY', 'MULTIPLE SCLEROSIS', 'NERVOUS SYSTEM DISORDERS',
           'ONCOLOGICS', 'OPHTHALMOLOGY, GENERAL', 'OTHER CNS', 'OTHER HAEMATOLOGICALS', 'VACCINES (PURE, COMB, OTHER)']

len(classes)
# Out:
# 11

# %%
for drug_class in classes:

    ########################
    # RETRIEVING DATA
    ########################

    # Retrieving all data about the drug class
    data = pd.read_csv('../2 Processed_Data/drugs_pct_changes_monthly.csv')
    data = data[data['Major Class'] == drug_class]
    data.Date = pd.to_datetime(data.Date, format='%Y_%m')

    # Only NDCs that have full period
    last_period = data[(data.Year == 2020) & (data.Month == 7)].NDC.unique()
    first_period = data[(data.Year == 2014) & (data.Month == 8)].NDC.unique()
    selected_NDC = list(set(last_period).intersection(first_period)) 
    data = data[data.NDC.isin(selected_NDC)]

    # Updating NDC that do not have LOE date to a future LOE date
    data.loc[data['Estimated LOE Date'] == 'Unspecified', 'Estimated LOE Date'] = 'May-24'

    # Getting rid of NDC that are too close to their LOE date
    data['Estimated LOE Date'] = pd.to_datetime(data['Estimated LOE Date'], format='%b-%y')
    data = data[data['Estimated LOE Date'] >= pd.to_datetime('2020-07-01')]

    # Retrieving year over year percent change data
    yy_data = pd.read_csv('../1 Data Preprocessing/Year Over Year/df_yearoveryear_class.csv')
    yy_data.Date = pd.to_datetime(yy_data.Date, format='%Y_%m')

    # Retrieving computed predictions
    prophet_1 = pd.read_csv(f'../4 Predictive Models/Results/Method 1/{drug_class}.csv')
    prophet_1 = prophet_1.rename(columns={'Unnamed: 0':'date', 'Number':'# price changes prediction', 'Percentage of drugs change price':'# price changes prediction (%)'})
    prophet_1.date = pd.to_datetime(prophet_1.date)

    prophet_2 = pd.read_csv(f'../4 Predictive Models/Results/Method 2/{drug_class}.csv')
    prophet_2.date = pd.to_datetime(prophet_2.date)



    ########################
    # BUILDING THE DELIVERABLE DATASET
    ########################

    # Extracting number of unique drug per month
    nb_drugs = data.groupby('Date')['NDC'].nunique().to_frame(name='# drugs').reset_index().rename(columns={'Date': 'date'})

    # Extracting year over year percent change in Sales weighted WAC
    yy_change = yy_data[yy_data['Major Class'] == drug_class][['Date', 'Class_wght_pct_change_y/y']].reset_index(drop=True).rename(columns={'Date': 'date', 'Class_wght_pct_change_y/y': 'Y/Y Percent change'})

    # Extracting number of changes per month
    nb_price_change = data.groupby('Date')['Changed'].sum().to_frame(name='# price changes').reset_index().rename(columns={'Date': 'date'})

    # Helper function
    def weigthed_average(data, quantity, weights):
        try:
            return (data[quantity] * data[weights]).sum() / data[weights].sum()
        except ZeroDivisionError:
            return data[quantity]    

    # Extracting Sales weighted WAC per month
    data['Sales'] = data['WAC'] * data['TRx']
    sales_wac = data.groupby('Date').apply(weigthed_average, 'WAC', 'Sales').to_frame(name = 'Sales weighted WAC').reset_index().rename(columns={'Date': 'date'})

    # Extracting TRx weighted WAC per month
    trx_wac = data.groupby('Date').apply(weigthed_average, 'WAC', 'TRx').to_frame(name = 'TRx weighted WAC').reset_index().rename(columns={'Date': 'date'})

    # Extracting Prophet 2 predictions
    prophet_2 = prophet_2[['date', 'yhat']].rename(columns={'yhat': 'Sales weighted WAC predictions'})

    # Merging all and formatting
    deliverable = nb_drugs.merge(yy_change, how='outer', on='date')
    deliverable = deliverable.merge(nb_price_change, how='outer', on='date')
    deliverable = deliverable.merge(sales_wac, how='outer', on='date')
    deliverable = deliverable.merge(trx_wac, how='outer', on='date')
    deliverable = deliverable.merge(prophet_1, how='outer', on='date')
    deliverable = deliverable.merge(prophet_2, how='outer', on='date')

    # Formatting date
    deliverable['Year'] = deliverable.date.dt.year
    deliverable['Month'] = deliverable.date.dt.month
    deliverable.drop('date', axis=1, inplace=True)

    # Creating handy class column
    deliverable['Class'] = drug_class

    # Computing percentage nb of drugs that have price change
    deliverable['# price changes (%)'] = deliverable['# price changes'] / deliverable['# drugs']

    # Computing M/M percent change
    deliverable['M/M Percent change'] = deliverable['Sales weighted WAC'].pct_change()
    deliverable['M/M Percent change predictions'] = deliverable['Sales weighted WAC predictions'].pct_change()

    # Cleaning year 2014
    deliverable = deliverable[deliverable.Year != 2014]

    # Creating actual + prediction column
    deliverable['Sales weighted WAC actual predictions'] = deliverable['Sales weighted WAC'].fillna(deliverable['Sales weighted WAC predictions'])

    # Creating date column - handier
    deliverable['Date'] = deliverable.Year.astype(str) + '-' + deliverable.Month.astype(str)
    deliverable['Date'] = pd.to_datetime(deliverable.Date)

    # Cleaning order column
    deliverable = deliverable[['Class', 'Date', 'Year', 'Month', 'Y/Y Percent change', '# drugs','# price changes', '# price changes (%)', '# price changes prediction', '# price changes prediction (%)',  'TRx weighted WAC', 'Sales weighted WAC', 'M/M Percent change', 'Sales weighted WAC predictions', 'M/M Percent change predictions']]

    deliverable.to_csv(f'Final deliverable Data/deliverable_{drug_class}.csv', index=False)

# %%
deliverable
# Out:
#                             Class       Date  Year  Month  Y/Y Percent change  \
# 5    VACCINES (PURE, COMB, OTHER) 2015-01-01  2015      1                 NaN
# 6    VACCINES (PURE, COMB, OTHER) 2015-02-01  2015      2                 NaN
# 7    VACCINES (PURE, COMB, OTHER) 2015-03-01  2015      3                 NaN
# 8    VACCINES (PURE, COMB, OTHER) 2015-04-01  2015      4                 NaN
# 9    VACCINES (PURE, COMB, OTHER) 2015-05-01  2015      5                 NaN
# 10   VACCINES (PURE, COMB, OTHER) 2015-06-01  2015      6                 NaN
# 11   VACCINES (PURE, COMB, OTHER) 2015-07-01  2015      7                 NaN
# 12   VACCINES (PURE, COMB, OTHER) 2015-08-01  2015      8            0.090608
# 13   VACCINES (PURE, COMB, OTHER) 2015-09-01  2015      9            0.102192
# 14   VACCINES (PURE, COMB, OTHER) 2015-10-01  2015     10            0.106534
# 15   VACCINES (PURE, COMB, OTHER) 2015-11-01  2015     11            0.057519
# 16   VACCINES (PURE, COMB, OTHER) 2015-12-01  2015     12            0.060054
# 17   VACCINES (PURE, COMB, OTHER) 2016-01-01  2016      1            0.059619
# 18   VACCINES (PURE, COMB, OTHER) 2016-02-01  2016      2            0.060335
# 19   VACCINES (PURE, COMB, OTHER) 2016-03-01  2016      3            0.032658
# 20   VACCINES (PURE, COMB, OTHER) 2016-04-01  2016      4            0.049450
# 21   VACCINES (PURE, COMB, OTHER) 2016-05-01  2016      5            0.049507
# 22   VACCINES (PURE, COMB, OTHER) 2016-06-01  2016      6            0.048457
# 23   VACCINES (PURE, COMB, OTHER) 2016-07-01  2016      7            0.047907
# 24   VACCINES (PURE, COMB, OTHER) 2016-08-01  2016      8            0.058556
# 25   VACCINES (PURE, COMB, OTHER) 2016-09-01  2016      9            0.062424
# 26   VACCINES (PURE, COMB, OTHER) 2016-10-01  2016     10            0.054311
# 27   VACCINES (PURE, COMB, OTHER) 2016-11-01  2016     11            0.060097
# 28   VACCINES (PURE, COMB, OTHER) 2016-12-01  2016     12            0.057299
# 29   VACCINES (PURE, COMB, OTHER) 2017-01-01  2017      1            0.054731
# 30   VACCINES (PURE, COMB, OTHER) 2017-02-01  2017      2            0.075285
# 31   VACCINES (PURE, COMB, OTHER) 2017-03-01  2017      3            0.076369
# 32   VACCINES (PURE, COMB, OTHER) 2017-04-01  2017      4            0.059644
# 33   VACCINES (PURE, COMB, OTHER) 2017-05-01  2017      5            0.062651
# 34   VACCINES (PURE, COMB, OTHER) 2017-06-01  2017      6            0.062533
# 35   VACCINES (PURE, COMB, OTHER) 2017-07-01  2017      7            0.062910
# 36   VACCINES (PURE, COMB, OTHER) 2017-08-01  2017      8            0.049057
# 37   VACCINES (PURE, COMB, OTHER) 2017-09-01  2017      9            0.063890
# 38   VACCINES (PURE, COMB, OTHER) 2017-10-01  2017     10            0.065106
# 39   VACCINES (PURE, COMB, OTHER) 2017-11-01  2017     11            0.029439
# 40   VACCINES (PURE, COMB, OTHER) 2017-12-01  2017     12            0.028655
# 41   VACCINES (PURE, COMB, OTHER) 2018-01-01  2018      1            0.065565
# 42   VACCINES (PURE, COMB, OTHER) 2018-02-01  2018      2            0.061017
# 43   VACCINES (PURE, COMB, OTHER) 2018-03-01  2018      3            0.061405
# 44   VACCINES (PURE, COMB, OTHER) 2018-04-01  2018      4            0.061758
# 45   VACCINES (PURE, COMB, OTHER) 2018-05-01  2018      5            0.052443
# 46   VACCINES (PURE, COMB, OTHER) 2018-06-01  2018      6            0.054257
# 47   VACCINES (PURE, COMB, OTHER) 2018-07-01  2018      7            0.054306
# 48   VACCINES (PURE, COMB, OTHER) 2018-08-01  2018      8            0.056528
# 49   VACCINES (PURE, COMB, OTHER) 2018-09-01  2018      9            0.043373
# 50   VACCINES (PURE, COMB, OTHER) 2018-10-01  2018     10            0.045399
# 51   VACCINES (PURE, COMB, OTHER) 2018-11-01  2018     11            0.044018
# 52   VACCINES (PURE, COMB, OTHER) 2018-12-01  2018     12            0.055625
# 53   VACCINES (PURE, COMB, OTHER) 2019-01-01  2019      1            0.019569
# 54   VACCINES (PURE, COMB, OTHER) 2019-02-01  2019      2            0.047168
# 55   VACCINES (PURE, COMB, OTHER) 2019-03-01  2019      3            0.046544
# 56   VACCINES (PURE, COMB, OTHER) 2019-04-01  2019      4            0.046042
# 57   VACCINES (PURE, COMB, OTHER) 2019-05-01  2019      5            0.046382
# 58   VACCINES (PURE, COMB, OTHER) 2019-06-01  2019      6            0.045467
# 59   VACCINES (PURE, COMB, OTHER) 2019-07-01  2019      7            0.044912
# 60   VACCINES (PURE, COMB, OTHER) 2019-08-01  2019      8            0.045979
# 61   VACCINES (PURE, COMB, OTHER) 2019-09-01  2019      9            0.063968
# 62   VACCINES (PURE, COMB, OTHER) 2019-10-01  2019     10            0.065139
# 63   VACCINES (PURE, COMB, OTHER) 2019-11-01  2019     11            0.064822
# 64   VACCINES (PURE, COMB, OTHER) 2019-12-01  2019     12            0.045921
# 65   VACCINES (PURE, COMB, OTHER) 2020-01-01  2020      1            0.045090
# 66   VACCINES (PURE, COMB, OTHER) 2020-02-01  2020      2            0.054305
# 67   VACCINES (PURE, COMB, OTHER) 2020-03-01  2020      3            0.057117
# 68   VACCINES (PURE, COMB, OTHER) 2020-04-01  2020      4            0.051454
# 69   VACCINES (PURE, COMB, OTHER) 2020-05-01  2020      5            0.049036
# 70   VACCINES (PURE, COMB, OTHER) 2020-06-01  2020      6            0.049800
# 71   VACCINES (PURE, COMB, OTHER) 2020-07-01  2020      7            0.051510
# 72   VACCINES (PURE, COMB, OTHER) 2020-08-01  2020      8                 NaN
# 73   VACCINES (PURE, COMB, OTHER) 2020-09-01  2020      9                 NaN
# 74   VACCINES (PURE, COMB, OTHER) 2020-10-01  2020     10                 NaN
# 75   VACCINES (PURE, COMB, OTHER) 2020-11-01  2020     11                 NaN
# 76   VACCINES (PURE, COMB, OTHER) 2020-12-01  2020     12                 NaN
# 77   VACCINES (PURE, COMB, OTHER) 2021-01-01  2021      1                 NaN
# 78   VACCINES (PURE, COMB, OTHER) 2021-02-01  2021      2                 NaN
# 79   VACCINES (PURE, COMB, OTHER) 2021-03-01  2021      3                 NaN
# 80   VACCINES (PURE, COMB, OTHER) 2021-04-01  2021      4                 NaN
# 81   VACCINES (PURE, COMB, OTHER) 2021-05-01  2021      5                 NaN
# 82   VACCINES (PURE, COMB, OTHER) 2021-06-01  2021      6                 NaN
# 83   VACCINES (PURE, COMB, OTHER) 2021-07-01  2021      7                 NaN
# 84   VACCINES (PURE, COMB, OTHER) 2021-08-01  2021      8                 NaN
# 85   VACCINES (PURE, COMB, OTHER) 2021-09-01  2021      9                 NaN
# 86   VACCINES (PURE, COMB, OTHER) 2021-10-01  2021     10                 NaN
# 87   VACCINES (PURE, COMB, OTHER) 2021-11-01  2021     11                 NaN
# 88   VACCINES (PURE, COMB, OTHER) 2021-12-01  2021     12                 NaN
# 89   VACCINES (PURE, COMB, OTHER) 2022-01-01  2022      1                 NaN
# 90   VACCINES (PURE, COMB, OTHER) 2022-02-01  2022      2                 NaN
# 91   VACCINES (PURE, COMB, OTHER) 2022-03-01  2022      3                 NaN
# 92   VACCINES (PURE, COMB, OTHER) 2022-04-01  2022      4                 NaN
# 93   VACCINES (PURE, COMB, OTHER) 2022-05-01  2022      5                 NaN
# 94   VACCINES (PURE, COMB, OTHER) 2022-06-01  2022      6                 NaN
# 95   VACCINES (PURE, COMB, OTHER) 2022-07-01  2022      7                 NaN
# 96   VACCINES (PURE, COMB, OTHER) 2022-08-01  2022      8                 NaN
# 97   VACCINES (PURE, COMB, OTHER) 2022-09-01  2022      9                 NaN
# 98   VACCINES (PURE, COMB, OTHER) 2022-10-01  2022     10                 NaN
# 99   VACCINES (PURE, COMB, OTHER) 2022-11-01  2022     11                 NaN
# 100  VACCINES (PURE, COMB, OTHER) 2022-12-01  2022     12                 NaN
# 101  VACCINES (PURE, COMB, OTHER) 2023-01-01  2023      1                 NaN
#
#      # drugs  # price changes  # price changes (%)  \
# 5       42.0              0.0             0.000000
# 6       42.0              0.0             0.000000
# 7       42.0              3.0             0.071429
# 8       42.0              0.0             0.000000
# 9       42.0              0.0             0.000000
# 10      42.0              2.0             0.047619
# 11      42.0              0.0             0.000000
# 12      42.0              0.0             0.000000
# 13      42.0              0.0             0.000000
# 14      42.0             13.0             0.309524
# 15      42.0              3.0             0.071429
# 16      42.0             13.0             0.309524
# 17      42.0              0.0             0.000000
# 18      42.0              0.0             0.000000
# 19      42.0              0.0             0.000000
# 20      42.0              3.0             0.071429
# 21      42.0              0.0             0.000000
# 22      42.0              0.0             0.000000
# 23      42.0              0.0             0.000000
# 24      42.0             12.0             0.285714
# 25      42.0              0.0             0.000000
# 26      42.0              0.0             0.000000
# 27      42.0              3.0             0.071429
# 28      42.0              0.0             0.000000
# 29      42.0              2.0             0.047619
# 30      42.0              3.0             0.071429
# 31      42.0              0.0             0.000000
# 32      42.0              0.0             0.000000
# 33      42.0             14.0             0.333333
# 34      42.0              0.0             0.000000
# 35      42.0              0.0             0.000000
# 36      42.0              3.0             0.071429
# 37      41.0             15.0             0.365854
# 38      41.0              0.0             0.000000
# 39      41.0              0.0             0.000000
# 40      41.0              0.0             0.000000
# 41      40.0              4.0             0.100000
# 42      40.0             12.0             0.300000
# 43      40.0              0.0             0.000000
# 44      39.0              0.0             0.000000
# 45      40.0              0.0             0.000000
# 46      40.0              0.0             0.000000
# 47      40.0              0.0             0.000000
# 48      40.0              0.0             0.000000
# 49      40.0              0.0             0.000000
# 50      39.0              0.0             0.000000
# 51      39.0              3.0             0.076923
# 52      39.0             13.0             0.333333
# 53      41.0              2.0             0.048780
# 54      41.0             17.0             0.414634
# 55      42.0              1.0             0.023810
# 56      42.0              0.0             0.000000
# 57      42.0              0.0             0.000000
# 58      42.0              0.0             0.000000
# 59      42.0              0.0             0.000000
# 60      42.0              0.0             0.000000
# 61      42.0             13.0             0.309524
# 62      42.0              1.0             0.023810
# 63      42.0              0.0             0.000000
# 64      42.0              0.0             0.000000
# 65      42.0              1.0             0.023810
# 66      42.0             18.0             0.428571
# 67      42.0              0.0             0.000000
# 68      42.0              0.0             0.000000
# 69      42.0              0.0             0.000000
# 70      42.0              0.0             0.000000
# 71      42.0              0.0             0.000000
# 72       NaN              NaN                  NaN
# 73       NaN              NaN                  NaN
# 74       NaN              NaN                  NaN
# 75       NaN              NaN                  NaN
# 76       NaN              NaN                  NaN
# 77       NaN              NaN                  NaN
# 78       NaN              NaN                  NaN
# 79       NaN              NaN                  NaN
# 80       NaN              NaN                  NaN
# 81       NaN              NaN                  NaN
# 82       NaN              NaN                  NaN
# 83       NaN              NaN                  NaN
# 84       NaN              NaN                  NaN
# 85       NaN              NaN                  NaN
# 86       NaN              NaN                  NaN
# 87       NaN              NaN                  NaN
# 88       NaN              NaN                  NaN
# 89       NaN              NaN                  NaN
# 90       NaN              NaN                  NaN
# 91       NaN              NaN                  NaN
# 92       NaN              NaN                  NaN
# 93       NaN              NaN                  NaN
# 94       NaN              NaN                  NaN
# 95       NaN              NaN                  NaN
# 96       NaN              NaN                  NaN
# 97       NaN              NaN                  NaN
# 98       NaN              NaN                  NaN
# 99       NaN              NaN                  NaN
# 100      NaN              NaN                  NaN
# 101      NaN              NaN                  NaN
#
#      # price changes prediction  # price changes prediction (%)  \
# 5                           0.0                        0.000000
# 6                           0.0                        0.000000
# 7                           2.0                        0.046875
# 8                           0.0                        0.000000
# 9                           0.0                        0.000000
# 10                          2.0                        0.046154
# 11                          0.0                        0.000000
# 12                          0.0                        0.000000
# 13                          0.0                        0.000000
# 14                         16.0                        0.371429
# 15                          2.0                        0.042254
# 16                         12.0                        0.273973
# 17                          1.0                        0.027397
# 18                          0.0                        0.000000
# 19                          0.0                        0.000000
# 20                          2.0                        0.041096
# 21                          0.0                        0.000000
# 22                          0.0                        0.000000
# 23                          0.0                        0.000000
# 24                          8.0                        0.186275
# 25                          0.0                        0.000000
# 26                          0.0                        0.000000
# 27                          2.0                        0.049020
# 28                          0.0                        0.000000
# 29                          2.0                        0.038462
# 30                          1.0                        0.028846
# 31                          1.0                        0.019231
# 32                          0.0                        0.000000
# 33                          9.0                        0.212389
# 34                          1.0                        0.017857
# 35                          0.0                        0.000000
# 36                          2.0                        0.045045
# 37                          9.0                        0.210526
# 38                          0.0                        0.007576
# 39                          0.0                        0.000000
# 40                          0.0                        0.006757
# 41                          2.0                        0.048611
# 42                          8.0                        0.184932
# 43                          0.0                        0.000000
# 44                          0.0                        0.006993
# 45                          0.0                        0.006993
# 46                          0.0                        0.006897
# 47                          0.0                        0.006803
# 48                          0.0                        0.000000
# 49                          0.0                        0.000000
# 50                          0.0                        0.000000
# 51                          1.0                        0.016854
# 52                          5.0                        0.116667
# 53                          1.0                        0.013605
# 54                         10.0                        0.227586
# 55                          1.0                        0.013514
# 56                          1.0                        0.013423
# 57                          0.0                        0.000000
# 58                          1.0                        0.013514
# 59                          0.0                        0.000000
# 60                          0.0                        0.000000
# 61                          6.0                        0.134228
# 62                          0.0                        0.005952
# 63                          0.0                        0.000000
# 64                          0.0                        0.000000
# 65                          1.0                        0.013889
# 66                         13.0                        0.312500
# 67                          0.0                        0.000000
# 68                          0.0                        0.000000
# 69                          0.0                        0.000000
# 70                          0.0                        0.000000
# 71                          0.0                        0.000000
# 72                          0.0                        0.000000
# 73                         20.0                        0.472222
# 74                          0.0                        0.000000
# 75                          2.0                        0.055556
# 76                          0.0                        0.000000
# 77                          0.0                        0.000000
# 78                         20.0                        0.472222
# 79                          0.0                        0.000000
# 80                          0.0                        0.000000
# 81                          0.0                        0.000000
# 82                          0.0                        0.000000
# 83                          NaN                             NaN
# 84                          NaN                             NaN
# 85                          NaN                             NaN
# 86                          NaN                             NaN
# 87                          NaN                             NaN
# 88                          NaN                             NaN
# 89                          NaN                             NaN
# 90                          NaN                             NaN
# 91                          NaN                             NaN
# 92                          NaN                             NaN
# 93                          NaN                             NaN
# 94                          NaN                             NaN
# 95                          NaN                             NaN
# 96                          NaN                             NaN
# 97                          NaN                             NaN
# 98                          NaN                             NaN
# 99                          NaN                             NaN
# 100                         NaN                             NaN
# 101                         NaN                             NaN
#
#      TRx weighted WAC  Sales weighted WAC  M/M Percent change  \
# 5          181.647703          211.979795            0.038649
# 6          182.768568          217.957136            0.028198
# 7          196.235034          231.375602            0.061565
# 8          195.698141          231.924880            0.002374
# 9          190.960344          228.860520           -0.013213
# 10         188.190005          226.286949           -0.011245
# 11         184.242014          224.009493           -0.010064
# 12         188.442203          230.133032            0.027336
# 13         225.205772          259.633697            0.128190
# 14         240.232997          268.674221            0.034820
# 15         236.147615          270.809289            0.007947
# 16         221.949888          259.133315           -0.043115
# 17         212.781801          254.807602           -0.016693
# 18         203.232189          246.978485           -0.030726
# 19         193.637620          238.970851           -0.032422
# 20         192.799564          237.778995           -0.004987
# 21         188.414123          234.241469           -0.014877
# 22         182.826672          229.603907           -0.019798
# 23         176.021496          225.344878           -0.018549
# 24         174.398273          228.337525            0.013280
# 25         217.075687          260.614586            0.141357
# 26         229.881797          267.821895            0.027655
# 27         233.624956          278.047416            0.038180
# 28         222.174970          269.238431           -0.031682
# 29         208.426499          262.106621           -0.026489
# 30         196.272761          253.031402           -0.034624
# 31         181.635137          239.314883           -0.054209
# 32         178.942723          236.083701           -0.013502
# 33         176.350775          233.142669           -0.012458
# 34         173.512243          229.740983           -0.014591
# 35         172.085649          226.944766           -0.012171
# 36         182.224763          238.604087            0.051375
# 37         210.019795          261.661936            0.096636
# 38         227.436902          272.240536            0.040429
# 39         223.711754          271.596669           -0.002365
# 40         214.464326          267.963200           -0.013378
# 41         211.013445          280.177496            0.045582
# 42         200.321199          273.677089           -0.023201
# 43         172.501016          251.888774           -0.079613
# 44         151.288536          236.682957           -0.060367
# 45         137.700653          222.596726           -0.059515
# 46         147.902080          231.749936            0.041120
# 47         148.036577          231.421527           -0.001417
# 48         165.405946          249.282397            0.077179
# 49         212.707346          283.411426            0.136909
# 50         232.394201          295.044471            0.041046
# 51         206.301906          282.069274           -0.043977
# 52         187.423846          268.167506           -0.049285
# 53         177.584151          259.605822           -0.031927
# 54         171.862774          260.082490            0.001836
# 55         164.158995          252.198952           -0.030312
# 56         148.704271          236.174179           -0.063540
# 57         138.945610          224.680131           -0.048668
# 58         142.054559          226.971065            0.010196
# 59         140.735415          224.512167           -0.010834
# 60         154.051716          241.297584            0.074764
# 61         210.920395          288.739580            0.196612
# 62         231.744071          300.438138            0.040516
# 63         215.710275          290.669078           -0.032516
# 64         191.186246          271.607958           -0.065577
# 65         176.456254          258.911992           -0.046744
# 66         175.712099          266.240099            0.028303
# 67         208.444817          292.461627            0.098488
# 68         156.339423          240.192536           -0.178721
# 69         141.678667          220.521183           -0.081898
# 70         146.077248          225.849692            0.024163
# 71         157.244083          242.030704            0.071645
# 72                NaN                 NaN            0.000000
# 73                NaN                 NaN            0.000000
# 74                NaN                 NaN            0.000000
# 75                NaN                 NaN            0.000000
# 76                NaN                 NaN            0.000000
# 77                NaN                 NaN            0.000000
# 78                NaN                 NaN            0.000000
# 79                NaN                 NaN            0.000000
# 80                NaN                 NaN            0.000000
# 81                NaN                 NaN            0.000000
# 82                NaN                 NaN            0.000000
# 83                NaN                 NaN            0.000000
# 84                NaN                 NaN            0.000000
# 85                NaN                 NaN            0.000000
# 86                NaN                 NaN            0.000000
# 87                NaN                 NaN            0.000000
# 88                NaN                 NaN            0.000000
# 89                NaN                 NaN            0.000000
# 90                NaN                 NaN            0.000000
# 91                NaN                 NaN            0.000000
# 92                NaN                 NaN            0.000000
# 93                NaN                 NaN            0.000000
# 94                NaN                 NaN            0.000000
# 95                NaN                 NaN            0.000000
# 96                NaN                 NaN            0.000000
# 97                NaN                 NaN            0.000000
# 98                NaN                 NaN            0.000000
# 99                NaN                 NaN            0.000000
# 100               NaN                 NaN            0.000000
# 101               NaN                 NaN            0.000000
#
#      Sales weighted WAC predictions  M/M Percent change predictions
# 5                        240.613581                             NaN
# 6                        240.026982                       -0.002438
# 7                        234.830320                       -0.021650
# 8                        226.819326                       -0.034114
# 9                        216.931874                       -0.043592
# 10                       216.657028                       -0.001267
# 11                       212.067283                       -0.021184
# 12                       225.140170                        0.061645
# 13                       262.472435                        0.165818
# 14                       274.780650                        0.046893
# 15                       269.597600                       -0.018862
# 16                       257.066460                       -0.046481
# 17                       245.228891                       -0.046049
# 18                       249.556009                        0.017645
# 19                       248.407129                       -0.004604
# 20                       227.713124                       -0.083307
# 21                       219.534640                       -0.035916
# 22                       222.080035                        0.011595
# 23                       228.284158                        0.027936
# 24                       237.611579                        0.040859
# 25                       265.132050                        0.115821
# 26                       271.934507                        0.025657
# 27                       274.459783                        0.009286
# 28                       265.059009                       -0.034252
# 29                       258.666854                       -0.024116
# 30                       247.976150                       -0.041330
# 31                       250.986250                        0.012139
# 32                       234.243818                       -0.066707
# 33                       225.486605                       -0.037385
# 34                       227.044257                        0.006908
# 35                       229.502788                        0.010828
# 36                       239.877760                        0.045206
# 37                       270.571988                        0.127958
# 38                       279.216949                        0.031951
# 39                       279.135836                       -0.000291
# 40                       268.580380                       -0.037815
# 41                       260.196991                       -0.031214
# 42                       254.423092                       -0.022190
# 43                       253.154575                       -0.004986
# 44                       240.569493                       -0.049713
# 45                       231.097787                       -0.039372
# 46                       231.564390                        0.002019
# 47                       230.279641                       -0.005548
# 48                       241.753066                        0.049824
# 49                       275.570112                        0.139883
# 50                       285.906217                        0.037508
# 51                       283.105222                       -0.009797
# 52                       271.360676                       -0.041485
# 53                       261.013001                       -0.038133
# 54                       260.098499                       -0.003504
# 55                       254.605668                       -0.021118
# 56                       246.266771                       -0.032752
# 57                       236.061995                       -0.041438
# 58                       235.459246                       -0.002553
# 59                       230.552175                       -0.020840
# 60                       243.298754                        0.055287
# 61                       280.304710                        0.152101
# 62                       292.297170                        0.042784
# 63                       286.787840                       -0.018848
# 64                       273.941437                       -0.044794
# 65                       261.778097                       -0.044401
# 66                       265.781796                        0.015294
# 67                       264.330363                       -0.005461
# 68                       243.312939                       -0.079512
# 69                       235.051060                       -0.033956
# 70                       237.510279                        0.010462
# 71                       243.634666                        0.025786
# 72                       252.879692                        0.037946
# 73                       280.320476                        0.108513
# 74                       287.045817                        0.023992
# 75                       289.492256                        0.008523
# 76                       280.015188                       -0.032737
# 77                       273.547072                       -0.023099
# 78                       262.780408                       -0.039359
# 79                       265.723912                        0.011201
# 80                       248.907748                       -0.063284
# 81                       240.080122                       -0.035465
# 82                       241.565013                        0.006185
# 83                       243.955871                        0.009897
# 84                       254.260915                        0.042241
# 85                       284.887398                        0.120453
# 86                       293.466799                        0.030115
# 87                       293.318498                       -0.000505
# 88                       282.698021                       -0.036208
# 89                       274.249167                       -0.029887
# 90                       268.409802                       -0.021292
# 91                       267.137973                       -0.004738
# 92                       254.549224                       -0.047125
# 93                       245.073969                       -0.037224
# 94                       245.537445                        0.001891
# 95                       244.249669                       -0.005245
# 96                       255.722431                        0.046971
# 97                       289.538813                        0.132239
# 98                       299.874668                        0.035698
# 99                       297.073413                       -0.009341
# 100                      285.328866                       -0.039534
# 101                      274.981192                       -0.036266
